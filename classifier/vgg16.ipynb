# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
from IPython.core.display import Image, display

# %%
vgg16 = VGG16(weights='imagenet')

# %%
def predict(img_file_path):
    display(Image(img_file_path, width=150, unconfined=True))
    img = image.load_img(img_file_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    preds = vgg16.predict(preprocess_input(x))

    # 予測確率が高いトップ5を出力
    top = 5
    results = decode_predictions(preds, top=top)[0]
    for result in results:
        print(result)

# %%
predict('./data/samples/strawberry1.jpg')
# Out:
# ('n07745940', 'strawberry', 0.99981064)
# ('n04476259', 'tray', 6.0705512e-05)
# ('n07753275', 'pineapple', 1.8244213e-05)
# ('n07930864', 'cup', 1.7782046e-05)
# ('n07836838', 'chocolate_sauce', 1.7597034e-05)

# %%
predict('./data/samples/cherry1.jpg')
# Out:
# ('n07768694', 'pomegranate', 0.42049336)
# ('n07745940', 'strawberry', 0.17790094)
# ('n12620546', 'hip', 0.088883184)
# ('n04332243', 'strainer', 0.075410224)
# ('n04522168', 'vase', 0.036265682)

# %%
predict('./data/samples/melon1.jpg')
# Out:
# ('n07742313', 'Granny_Smith', 0.7975601)
# ('n07718472', 'cucumber', 0.052942749)
# ('n04409515', 'tennis_ball', 0.027609043)
# ('n07930864', 'cup', 0.013589498)
# ('n07753592', 'banana', 0.012850583)

# %%
predict('./data/samples/banana1.jpg')
# Out:
# ('n07753592', 'banana', 0.98944634)
# ('n07753275', 'pineapple', 0.00314941)
# ('n07716906', 'spaghetti_squash', 0.0028294064)
# ('n07747607', 'orange', 0.0010036825)
# ('n07749582', 'lemon', 0.00094224227)
